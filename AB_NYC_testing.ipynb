# %% [markdown]
# <a href="https://colab.research.google.com/github/pin94/my-notebook/blob/main/AB_NYC_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
myDirFiles='/content/drive/MyDrive/AB_NYC_2019 - AB_NYC_2019.csv'
df=pd.read_csv(myDirFiles,delimiter=',')

# %%
df
# Out:
#              id                                               name    host_id  \
# 0      18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 1      20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 2      20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 3      20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 4      20624541      Modern apartment in the heart of Williamsburg   10132166
# ...         ...                                                ...        ...
# 48890   9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 48891  31340283  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# 48892   7003697                Furnished room in Astoria apartment   20582832
# 48893  13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 48894  22436899                                1-BR Lincoln Center   72390391
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df2=df.dropna()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38821 entries, 0 to 48893
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              38821 non-null  int64
#  1   name                            38821 non-null  object
#  2   host_id                         38821 non-null  int64
#  3   host_name                       38821 non-null  object
#  4   neighbourhood_group             38821 non-null  object
#  5   neighbourhood                   38821 non-null  object
#  6   latitude                        38821 non-null  float64
#  7   longitude                       38821 non-null  float64
#  8   room_type                       38821 non-null  object
#  9   price                           38821 non-null  int64
#  10  minimum_nights                  38821 non-null  int64
#  11  number_of_reviews               38821 non-null  int64
# ...

# %%
import plotly.express as px
fig = px.box(df2, y="price")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def find_outliers_IQR(df2):
  q1=df2.quantile(0.25)
  q3=df2.quantile(0.75)
  IQR=q3-q1
  outliers = df2[((df2<(q1-1.5*IQR)) | (df2>(q3+1.5*IQR)))]
  
  return outliers

# %%
outliers = find_outliers_IQR(df2.price)

print('number of outliers: '+ str(len(outliers)))

print('max outlier value: '+ str(outliers.max()))

print('min outlier value: '+ str(outliers.min()))

outliers
# Out:
# number of outliers: 2077
# max outlier value: 10000
# min outlier value: 322
# 45736      322
# 45738      323
# 45739      324
# 45740      324
# 45741      325
#          ...
# 48888     8500
# 48889     9999
# 48890     9999
# 48892    10000
# 48893    10000
# Name: price, Length: 2077, dtype: int64

# %%
outliers = find_outliers_IQR(df2[['price','minimum_nights']])
outliers
# Out:
#          price  minimum_nights
# 0          NaN             NaN
# 1          NaN             NaN
# 2          NaN             NaN
# 3          NaN             NaN
# 4          NaN             NaN
# ...        ...             ...
# 48888   8500.0            30.0
# 48889   9999.0             NaN
# 48890   9999.0            99.0
# 48892  10000.0           100.0
# 48893  10000.0             NaN
#
# [38821 rows x 2 columns]

# %%
def drop_outliers_IQR(df2):
  q1=df2.quantile(0.25)
  q3=df2.quantile(0.75)
  IQR=q3-q1
  not_outliers = df2[~((df2<(q1-1.5*IQR)) | (df2>(q3+1.5*IQR)))]
  outliers_dropped = outliers.dropna(inplace=True).reset_index()
  return outliers_dropped

# %%
df2
# Out:
#              id                                               name    host_id  \
# 0      18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 1      20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 2      20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 3      20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 4      20624541      Modern apartment in the heart of Williamsburg   10132166
# ...         ...                                                ...        ...
# 48888  23377410  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho   18128455
# 48889   4737930                                 Spanish Harlem Apt    1235070
# 48890   9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 48892   7003697                Furnished room in Astoria apartment   20582832
# 48893  13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
#
# ...

# %%
from scipy import stats
 
z = np.abs(stats.zscore(df2.price))
print(z)
# Out:
# 0         0.722529
# 1         0.722529
# 2         0.722529
# 3         0.722529
# 4         0.722529
#            ...
# 48888    42.426384
# 48889    50.035821
# 48890    50.035821
# 48892    50.040898
# 48893    50.040898
# Name: price, Length: 38821, dtype: float64

# %%
threshold = 3
 
# Position of the outlier
print(np.where(z > 3))
# Out:
# (array([38509, 38510, 38511, 38512, 38513, 38514, 38515, 38516, 38517,
#        38518, 38519, 38520, 38521, 38522, 38523, 38524, 38525, 38526,
#        38527, 38528, 38529, 38530, 38531, 38532, 38533, 38534, 38535,
#        38536, 38537, 38538, 38539, 38540, 38541, 38542, 38543, 38544,
#        38545, 38546, 38547, 38548, 38549, 38550, 38551, 38552, 38553,
#        38554, 38555, 38556, 38557, 38558, 38559, 38560, 38561, 38562,
#        38563, 38564, 38565, 38566, 38567, 38568, 38569, 38570, 38571,
#        38572, 38573, 38574, 38575, 38576, 38577, 38578, 38579, 38580,
#        38581, 38582, 38583, 38584, 38585, 38586, 38587, 38588, 38589,
#        38590, 38591, 38592, 38593, 38594, 38595, 38596, 38597, 38598,
#        38599, 38600, 38601, 38602, 38603, 38604, 38605, 38606, 38607,
#        38608, 38609, 38610, 38611, 38612, 38613, 38614, 38615, 38616,
#        38617, 38618, 38619, 38620, 38621, 38622, 38623, 38624, 38625,
# ...

# %%
df2.drop(df2[df2.price >= 38509].index, inplace = True)
df2
# Out:
# <ipython-input-65-8c02965986a3>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              id                                               name    host_id  \
# 0      18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 1      20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 2      20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 3      20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 4      20624541      Modern apartment in the heart of Williamsburg   10132166
# ...         ...                                                ...        ...
# 48888  23377410  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho   18128455
# 48889   4737930                                 Spanish Harlem Apt    1235070
# ...

# %%
df2.replace(0, np.nan, inplace=True)
# Out:
# <ipython-input-68-ce1c8e199b7f>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2.dropna(inplace=True)
df2
# Out:
# <ipython-input-70-2190fdf45efb>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              id                                               name    host_id  \
# 15     18490141                            IT'S SIMPLY CONVENIENT!   97001292
# 18     21869057      Spacious 2-bedroom Apt in Heart of Greenpoint   11967922
# 20     24412104                           Cozy feel at home studio   91034542
# 21     25839759  Gigantic Sunny Room in Park Slope-Private Back...  167570251
# 22     26235873                             Voted #1 Airbnb In NYC  197169969
# ...         ...                                                ...        ...
# 48877   2110145                 UWS 1BR w/backyard + block from CP    2151325
# 48885  34895693                               Gem of east Flatbush  262534951
# ...

# %%
df2.id = df2.id.astype(str)
df2.id = df2.id.str.zfill(8)
df2
# Out:
# <ipython-input-73-74d7bebb9409>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-73-74d7bebb9409>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              id                                               name    host_id  \
# 15     18490141                            IT'S SIMPLY CONVENIENT!   97001292
# 18     21869057      Spacious 2-bedroom Apt in Heart of Greenpoint   11967922
# 20     24412104                           Cozy feel at home studio   91034542
# ...

# %%
df2.host_id.sort_values()
# Out:
# 37469         2571
# 31730         2787
# 21326         2787
# 31632         2787
# 4830          2787
#            ...
# 11636    272557707
# 35861    272816114
# 47       272872092
# 25454    273361532
# 23925    273841667
# Name: host_id, Length: 26138, dtype: int64

# %%
df2.host_id=df2.host_id.astype(str)
df2.host_id=df2.host_id.str.zfill(9)
df2
# Out:
# <ipython-input-76-e714f7192fff>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-76-e714f7192fff>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              id                                               name    host_id  \
# 15     18490141                            IT'S SIMPLY CONVENIENT!  097001292
# 18     21869057      Spacious 2-bedroom Apt in Heart of Greenpoint  011967922
# 20     24412104                           Cozy feel at home studio  091034542
# ...

# %%
df2.reset_index(inplace=True)

# %%
import os
os.makedirs('/content/drive/MyDrive/Colab Notebooks', exist_ok=True)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/tugas1_[NAMA]_data_analyst.csv')
